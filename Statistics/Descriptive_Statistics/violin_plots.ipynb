# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
import scipy.stats as st

# %%
n    = 1000
data = np.exp( np.random.randn(n) )

# %%
sns.kdeplot(data)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.violinplot(data , fill=False)
# Out:
# <Axes: >
