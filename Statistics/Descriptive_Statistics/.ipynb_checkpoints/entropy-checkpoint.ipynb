# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
## "discrete" entropy

# generate data
N = 1000
numbers = np.ceil( 8*np.random.rand(N)**2 )
sns.histplot(numbers , bins=5)
# Out:
# <Axes: ylabel='Count'>

# %%
u = np.unique(numbers)
probs = np.zeros(len(u))

for ui in range(len(u)):
    probs[ui] = sum(numbers==u[ui]) / N
# compute entropy
entropee = -sum( probs*np.log2(probs) )
print(entropee)

# plot
plt.bar(u,probs)
plt.title('Entropy = %g'%entropee)
plt.xlabel('Data value')
plt.ylabel('Probability')
plt.show()
# Out:
# 2.7027678624286144

# %%
## for random variables

# create Brownian noise
N = 1123
brownnoise = np.cumsum( np.sign(np.random.randn(N)) ) # prefix sum #

fig,ax = plt.subplots(2,1,figsize=(4,6))
ax[0].plot(brownnoise)
ax[0].set_xlabel('Data index')
ax[0].set_ylabel('Data value')
ax[0].set_title('Brownian noise')

ax[1].hist(brownnoise,30)
ax[1].set_xlabel('Data value')
ax[1].set_ylabel('Counts')
plt.show()
# Out:
# [ 1.  2.  3. ... 15. 14. 15.]

# %%
### now compute entropy
# number of bins
nbins = 20

# bin the data and convert to probability
nPerBin,bins = np.histogram(brownnoise,nbins)
probs = nPerBin / sum(nPerBin)

# compute entropy
entro = -sum( probs*np.log2(probs) )

print('Entropy = %g'%entro)
# Out:
# Entropy = 3.79123
