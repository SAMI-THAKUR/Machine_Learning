# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://drive.google.com/file/d/1VzAeJybW9OCaYaz706te9wHJM_6wvyt9/view?usp=drive_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
sales= pd.read_csv(url)
sales
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %% [markdown]
# <h2><mark>Simple CountPlot</mark></h2>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(data=sales , x='division')
# Out:
# <Axes: xlabel='division', ylabel='count'>

# %%
plt.figure(figsize=(20,4),dpi=100)
sns.countplot(data=sales , x='level of education')
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %% [markdown]
# <h2><mark>Breakdown with hue</mark></h2>

# %%
plt.figure(figsize=(20,5) , dpi=100)
sns.countplot(data=sales , x='level of education' , hue='training level')
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %% [markdown]
# <h2><mark>BarPlot</mark></h2>

# %% [markdown]
# <b><mark>so the bar plot below shows the mean salary on Y and education on X and the black line shows S.D i.e master degree has least standard deviation</mark></b><br><p>Not a good way of demonstating it</p>

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.barplot(x='level of education', y='sales', data=sales, estimator=np.mean, errorbar='sd')
plt.xlabel('Level of Education')
plt.ylabel('Mean Sales')
plt.title('Mean Sales by Level of Education')
plt.show()
