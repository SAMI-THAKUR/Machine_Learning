# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://drive.google.com/file/d/1d1ddBCAIj5s5wsd01tvTG51gcOQKwg8s/view?usp=drive_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
fig,axes = plt.subplots(nrows=1 , ncols=2)
sns.jointplot(data=df , x='math score',y='reading score')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 fig,axes = plt.subplots(nrows=1 , ncols=2)
# ----> 2 sns.jointplot(data=df , x='math score',y='reading score' , axes=axes[0])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:2257, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2254 if kind.startswith("scatter"):
#    2256     joint_kws.setdefault("color", color)
# -> 2257     grid.plot_joint(scatterplot, **joint_kws)
#    2259     if grid.hue is None:
#    2260         marg_func = histplot
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:1832, in JointGrid.plot_joint(self, func, **kwargs)
#    1829     self._inject_kwargs(func, kwargs, self._hue_params)
#    1831 if str(func.__module__).startswith("seaborn"):
# -> 1832     func(x=self.x, y=self.y, **kwargs)
#    1833 else:
#    1834     func(self.x, self.y, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:631, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     628 color = kwargs.pop("color", None)
#     629 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 631 p.plot(ax, kwargs)
#     633 return ax
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:433, in _ScatterPlotter.plot(self, ax, kws)
#     430     kws.setdefault("edgecolor", "w")
#     432 # Draw the scatter plot
# --> 433 points = ax.scatter(x=x, y=y, **kws)
#     435 # Apply the mapping from semantic variables to artist attributes
#     437 if "hue" in self.variables:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:4779, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4776     if self._ymargin < 0.05 and x.size > 0:
#    4777         self.set_ymargin(0.05)
# -> 4779 self.add_collection(collection)
#    4780 self._request_autoscale_view()
#    4782 return collection
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:2260, in _AxesBase.add_collection(self, collection, autolim)
#    2258 self._children.append(collection)
#    2259 collection._remove_method = self._children.remove
# -> 2260 self._set_artist_props(collection)
#    2262 if collection.get_clip_path() is None:
#    2263     collection.set_clip_path(self.patch)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:1177, in _AxesBase._set_artist_props(self, a)
#    1174 if not a.is_transform_set():
#    1175     a.set_transform(self.transData)
# -> 1177 a.axes = self
#    1178 if a.get_mouseover():
#    1179     self._mouseover_set.add(a)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\artist.py:302, in Artist.axes(self, new_axes)
#     298 @axes.setter
#     299 def axes(self, new_axes):
#     300     if (new_axes is not None and self._axes is not None
#     301             and new_axes != self._axes):
# --> 302         raise ValueError("Can not reset the axes.  You are probably "
#     303                          "trying to re-use an artist in more than one "
#     304                          "Axes which is not supported")
#     305     self._axes = new_axes
#     306     if new_axes is not None and new_axes is not self:
#
# ValueError: Can not reset the axes.  You are probably trying to re-use an artist in more than one Axes which is not supported
