# %%
import pandas as pd
import numpy as np

# %%
teamMembers = [
    { "name": "Shreyash Bhute", "post": "Jr. Operations Officer" , "cgpa":10},
    { "name": "Arya Madhavi", "post": "Jr. Operations Officer", "mail": "2022.arya.madhavi@ves.ac.in" , "cgpa":10 },
    { "name": "Surel Sanap", "post": "Jr. Public Relations Officer", "mail": "2022.surel.sanap@ves.ac.in"  , "cgpa":10},
    { "name": "Simran Godhwani", "post": "Jr. Public Relations Officer", "mail": "2022.simran.godhwani@ves.ac.in"  , "cgpa":9},
    { "cgpa":8},
    { "name": "Aditya Kumar", "post": "Jr. Web Editor", "mail": "2022.aditya.sampathkumar@ves.ac.in"  , "cgpa":9},
    { "name": "Karan Bhatia", "post": "Jr. Web Editor", "mail": "2022.karan.bhatia@ves.ac.in"  , "cgpa":8},
    { "name": "Sami Thakur", "post": "Jr. Technical Officer", "mail": "2022.sami.thakur@ves.ac.in"  , "cgpa":9},
    { "name": "Sagar Rajak", "post": "Jr. Technical Officer", "mail": "2022.sagar.rajak@ves.ac.in"  , "cgpa":8},
    {"name":""  , "cgpa":10},
    { "name": "Anish Padhye", "post": "Jr. Editor", "mail": "2022.anish.padhye@ves.ac.in" , "cgpa":9 },
]

# %%
df= pd.DataFrame(teamMembers)

# %%
df
# Out:
#                name                          post  cgpa  \
# 0    Shreyash Bhute        Jr. Operations Officer    10
# 1      Arya Madhavi        Jr. Operations Officer    10
# 2       Surel Sanap  Jr. Public Relations Officer    10
# 3   Simran Godhwani  Jr. Public Relations Officer     9
# 4               NaN                           NaN     8
# 5      Aditya Kumar                Jr. Web Editor     9
# 6      Karan Bhatia                Jr. Web Editor     8
# 7       Sami Thakur         Jr. Technical Officer     9
# 8       Sagar Rajak         Jr. Technical Officer     8
# 9                                             NaN    10
# 10     Anish Padhye                    Jr. Editor     9
#
#                                   mail
# 0                                  NaN
# 1          2022.arya.madhavi@ves.ac.in
# 2           2022.surel.sanap@ves.ac.in
# 3       2022.simran.godhwani@ves.ac.in
# 4                                  NaN
# 5   2022.aditya.sampathkumar@ves.ac.in
# ...

# %%
df["post"].value_counts()
# Out:
# post
# Jr. Operations Officer          2
# Jr. Public Relations Officer    2
# Jr. Web Editor                  2
# Jr. Technical Officer           2
# Jr. Editor                      1
# Name: count, dtype: int64

# %%
df.groupby(["post","cgpa"]).sum()
# all agregation model #
df.groupby(["post","cgpa"]).describe().transpose()
# Out:
# post                          Jr. Editor       Jr. Operations Officer  \
# cgpa                                  9                            10
# name count                             1                            2
#      unique                            1                            2
#      top                    Anish Padhye               Shreyash Bhute
#      freq                              1                            1
# mail count                             1                            1
#      unique                            1                            1
#      top     2022.anish.padhye@ves.ac.in  2022.arya.madhavi@ves.ac.in
#      freq                              1                            1
#
# post           Jr. Public Relations Officer                              \
# cgpa                                     9                           10
# name count                                1                           1
# ...

# %%
gr = df.groupby(["cgpa","post"]).sum()
gr.index.levels
gr
# Out:
#                                                          name  \
# cgpa post
# 8    Jr. Technical Officer                        Sagar Rajak
#      Jr. Web Editor                              Karan Bhatia
# 9    Jr. Editor                                  Anish Padhye
#      Jr. Public Relations Officer             Simran Godhwani
#      Jr. Technical Officer                        Sami Thakur
#      Jr. Web Editor                              Aditya Kumar
# 10   Jr. Operations Officer        Shreyash BhuteArya Madhavi
#      Jr. Public Relations Officer                 Surel Sanap
#
#                                                                  mail
# cgpa post
# 8    Jr. Technical Officer                 2022.sagar.rajak@ves.ac.in
#      Jr. Web Editor                       2022.karan.bhatia@ves.ac.in
# 9    Jr. Editor                           2022.anish.padhye@ves.ac.in
#      Jr. Public Relations Officer      2022.simran.godhwani@ves.ac.in
# ...

# %%
gr.loc[(10 , "Jr. Public Relations Officer")]
# Out:
# name                   Surel Sanap
# mail    2022.surel.sanap@ves.ac.in
# Name: (10, Jr. Public Relations Officer), dtype: object

# %%
gr.xs(key=10 , level="cgpa")
gr.loc[[9,10],"name"]
gr.xs(key="Jr. Technical Officer" , level="post")
# Out:
#              name                        mail
# cgpa
# 8     Sagar Rajak  2022.sagar.rajak@ves.ac.in
# 9     Sami Thakur  2022.sami.thakur@ves.ac.in

# %%
new = df[df["cgpa"].isin([9,10])].groupby(["cgpa","post"]).sum()
new.swaplevel()
# df.agg(["std","mean"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# ...
