# %%
import pandas as pd

# %%
survey = pd.read_csv('DATA/stack_overflow/survey_results_public.csv' , index_col = "ResponseId") 
# survey.set_index("ResponseId" , inplace = True)
# setting id as index  help full in data that has some uique id #
schema = pd.read_csv('DATA/stack_overflow/survey_results_schema.csv' , index_col="qname")

# %%
# setting up pandas display options #
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 50)

# %%
# prints the number of rows and columns #
survey.shape
schema.shape
# Out:
# (79, 5)

# %%
survey.head(10) # prints the first 10 rows #
# survey.tail(2) # prints the last 2 rows #
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# 6           I am not primarily a developer, but I write co...
# 7                                 I code primarily as a hobby
# 8                              I am a developer by profession
# 9                              I am a developer by profession
# 10                             I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# ...

# %%
schema.info # prints the info about the data frame #
schema.dtypes # prints the data types of the columns #
# Out:
# qid           object
# question      object
# force_resp    object
# type          object
# selector      object
# dtype: object

# %%
survey.shape
# Out:
# (73268, 78)

# %%
survey["Age"].value_counts() # prints the count of each value in the column #
# Out:
# Age
# 25-34 years old       28112
# 18-24 years old       16646
# 35-44 years old       13988
# 45-54 years old        5281
# Under 18 years old     3866
# 55-64 years old        1978
# 65 years or older       554
# Prefer not to say       521
# Name: count, dtype: int64

# %%
survey.loc[0:10,'YearsCode':'DevType']
# Out:
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                NaN          NaN
# 3                 14            5
# 4                 20           17
# 5                  8            3
# 6                 15          NaN
# 7                  3          NaN
# 8                  1          NaN
# 9                  6            6
# 10                37           30
#
#                                                       DevType
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Data scientist or machine learning specialist;...
# 4                                       Developer, full-stack
# 5           Developer, front-end;Developer, full-stack;Dev...
# 6                                                         NaN
# 7                                                         NaN
# ...

# %%
survey.loc[10:25, "MainBranch"] # prints the values of the column from 10 to 25 for the column MainBranch #
# Out:
# ResponseId
# 10                       I am a developer by profession
# 11                       I am a developer by profession
# 12    I am not primarily a developer, but I write co...
# 13                       I am a developer by profession
# 14                       I am a developer by profession
# 15                       I am a developer by profession
# 16                       I am a developer by profession
# 17                       I am a developer by profession
# 18                       I am a developer by profession
# 19                       I am a developer by profession
# 20                                I am learning to code
# 21                       I am a developer by profession
# 22                       I am a developer by profession
# 23                       I am a developer by profession
# 24    I am not primarily a developer, but I write co...
# 25                       I am a developer by profession
# Name: MainBranch, dtype: object

# %%
schema.loc["Ethnicity" , "question"]
# Out:
# 'Which of the following describe you, if any? Please check all that apply.'

# %%
schema.sort_index(ascending = False).tail(50)
# Out:
#                          qid  \
# qname
# S2                    QID190
# S1                      QID1
# S0                     QID16
# RemoteWork            QID308
# PurchaseInfluence     QID278
# ProfessionalTech      QID304
# Platform              QID263
# OrgSize                QID29
# OpSys                  QID71
# Onboarding            QID293
# OfficeStackSync       QID307
# OfficeStackAsync      QID282
# NEWSOSites            QID266
# NEWCollabTools        QID274
# MiscTech              QID265
# MetaInfo               QID12
# MentalHealth          QID125
# MainBranch              QID2
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# LearnCode             QID276
# Language              QID233
# Knowledge_7           QID289
# Knowledge_6           QID289
# Knowledge_5           QID289
# Knowledge_4           QID289
# Knowledge_3           QID289
# Knowledge_2           QID289
# Knowledge_1           QID289
# Knowledge             QID289
# ...

# %%
f1  = (survey["CompTotal"] > 2000000)
countries = ["India" , "United Kingdom"]
f2 = (survey["Country"].isin(countries)) 
f3 = (survey["LanguageHaveWorkedWith"].str.contains("Python" , na=False))
survey.loc[f1 , "Country"].value_counts()
survey.loc[f1&f2&f3 , ["LanguageHaveWorkedWith","Country"]]
# Out:
#                                        LanguageHaveWorkedWith Country
# ResponseId
# 197                                    Python;Rust;TypeScript   India
# 571                                             C++;Go;Python   India
# 783                                               Java;Python   India
# 942              Bash/Shell;Go;JavaScript;Lua;Python;Rust;SQL   India
# 1133                                             C;C++;Python   India
# ...                                                       ...     ...
# 71386                   Go;HTML/CSS;JavaScript;PHP;Python;SQL   India
# 71395                                     Haskell;Java;Python   India
# 71834                                  Groovy;Java;Python;SQL   India
# 71909       Bash/Shell;C++;Groovy;Java;JavaScript;Python;Ruby   India
# 72679                              Bash/Shell;Java;Python;SQL   India
#
# [262 rows x 2 columns]

# %%
survey.sort_values(by="YearsCode")
# Out:
#                                                    MainBranch  \
# ResponseId
# 49353       I used to be a developer by profession, but no...
# 28465                                   I am learning to code
# 17781                             I code primarily as a hobby
# 8079                                    I am learning to code
# 17783                                   I am learning to code
# ...                                                       ...
# 73110                                           None of these
# 73158                                           None of these
# 73202                                           None of these
# 73216                                           None of these
# 73244                                           None of these
#
#                                                    Employment  \
# ResponseId
# 49353                                     Employed, full-time
# 28465                      Not employed, but looking for work
# ...
