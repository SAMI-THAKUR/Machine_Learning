# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("dm_office_sales.csv")
data["work experience"].value_counts()
data
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
# RugPlot : individual data points are depicted as small marks or "ticks" along the axis, resembling the fringes of a rug.
# Histogram : frequency distribution of a set of continuous or discrete data
# KDE : is a method for smoothing a histogram to obtain a continuous probability distribution

# %%
plt.figure(figsize=(8,8))
sns.rugplot(x="salary" , data=data , height=0.5)
# Out:
# <Axes: xlabel='salary'>

# %%
sns.set(style="darkgrid")
sns.displot(x="work experience" , data=data ,bins=16 , kde=True , rug=True)

# %%
sns.kdeplot(data=data , x="work experience" , clip=[0,100])
# Out:
# <Axes: xlabel='work experience', ylabel='Density'>

# %%
sns.histplot(data=data , x="work experience")
# Out:
# <Axes: xlabel='work experience', ylabel='Count'>
