# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randint(0,100 , 10)
y = 2*x
# Out:
# array([82, 77, 11, 74, 32, 84, 60, 11, 73, 77])

# %%
plt.plot(x,y);
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('Graph Title Here')
plt.xlim(0,70)
plt.savefig('example.png')

# %%
# You can add as many axes on to the same figure as you want, 
# even outside of the main figure if the length and width correspond to this.

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1]) # Large figure
axes2 = fig.add_axes([0.2, 0.5, 0.25, 0.25]) # Smaller figure

# Larger Figure Axes 1
axes1.plot(a, b)

# Use set_ to add to the axes figure
axes1.set_xlabel('X Label')
axes1.set_ylabel('Y Label')
axes1.set_title('Big Figure')

# Insert Figure Axes 2
axes2.plot(a,b)
axes2.set_xlim(8,10)
axes2.set_ylim(4000,10000)
axes2.set_xlabel('X')
axes2.set_ylabel('Y')
axes2.set_title('Zoomed In');
